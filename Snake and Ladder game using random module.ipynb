# %%
import random
p1=0
p2=0
snakebit={17:7,54:34,62:19,64:60,87:36,92:73,95:75,98:79}
ladder={1:38,4:14,21:42,9:31,28:84,51:67,72:91,80:99}
def SnakeAndladder(pos):
    dice=random.randint(1,6)
    print("Dice:{}".format(dice))
    pos=pos+dice
    if pos in snakebit:
        print("snake bitten")
        pos=snakebit[pos]
        print("Present position:{}".format(pos))
    elif pos in ladder:
        print("Climbed by ladder")
        pos=ladder[pos]
        print("Present position:{}".format(pos))
    else:
        print("Present position:{}".format(pos))
    print("\n")
    return pos
while True:
    Raghu=input("player 1 enter\"Raghu\" to throw dice :")
    p1=SnakeAndladder(p1)
    if p1>=100:
        print("Game over!!!\n Raghu wins")
        break
    Rohan=input("player 1 enter\"Rohan\" to throw dice :")
    p2=SnakeAndladder(p2)
    if p2>=100:
        print("Game over!!!\n Rohan wins")
        break
# Out:
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:6
# Present position:6
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:5
# Present position:5
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:1
# Present position:7
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:6
# Present position:11
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:4
# Present position:11
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:3
# Present position:14
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:4
# Present position:15
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:4
# Present position:18
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:5
# Present position:20
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:6
# Present position:24
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:3
# Present position:23
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:2
# Present position:26
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:6
# Present position:29
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:1
# Present position:27
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:2
# Present position:31
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:4
# Present position:31
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:2
# Present position:33
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:5
# Present position:36
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:6
# Present position:39
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:6
# Present position:42
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:2
# Present position:41
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:2
# Present position:44
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:2
# Present position:43
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:4
# Present position:48
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:5
# Present position:48
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:2
# Present position:50
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:3
# Climbed by ladder
# Present position:67
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:4
# snake bitten
# Present position:34
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:3
# Present position:70
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:1
# Present position:35
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:6
# Present position:76
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:5
# Present position:40
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:6
# Present position:82
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:1
# Present position:41
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:2
# Present position:84
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:3
# Present position:44
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:2
# Present position:86
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:6
# Present position:50
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:3
# Present position:89
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:1
# Climbed by ladder
# Present position:67
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:2
# Present position:91
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:6
# Present position:73
#
#
# player 1 enter"Raghu" to throw dice :Raghu'
# Dice:5
# Present position:96
#
#
# player 1 enter"Rohan" to throw dice :Rohan
# Dice:3
# Present position:76
#
#
# player 1 enter"Raghu" to throw dice :Raghu
# Dice:4
# Present position:100
#
#
# Game over!!!
#  Raghu wins
